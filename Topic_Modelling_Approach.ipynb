# %%
import pandas as pd
import re

# %%
! pip install fasttext-langdetect

# %% [markdown]
# ## Task
#
# For the test task you need to extract primary topics or narratives from the provided texts. Your outputs must be interpretable, i.e. by looking at them a reader must be able to get an impression of what processed texts are about.
#
# ## Solution
#
# In my solution I am going to show an approach and thoughts about possibe approachess rather than high metrics as they require a lot of time to tune and get to the point that we need.
# So I gave a detailed descriptions for each step - what we do and why and provided examples for middle steps.

# %% [markdown]
# ## Reading & overview on data

# %%
data = pd.read_csv('/content/test_assignment_data.csv')

# %%
data.head()
# Out:
#                                             fullText     pubTime
# 0  Бабушкинский суд столицы приговорил трех актив...  2024-02-19
# 1  Бывшего совладельца сетей "Кофе хауз" и "Азбук...  2024-02-19
# 2  Ежегодный фестиваль исторических садов пройдет...  2024-02-19
# 3  На улицах Москвы появилось свыше 120 светоотра...  2024-02-19
# 4  Три дома, в которых в свое время жили сотрудни...  2024-02-19

# %%
# more detailed look to the texts

data['fullText'].sample(5).values
# Out:
# array(['Президент Сербии отметил, что введение мер против Москвы было бы несправедливым по отношению к русскому народуБЕЛГРАД, 20 февраля. /ТАСС/. Президент Сербии Александар Вучич намерен сохранять независимую политику по отказу от антироссийских санкций, несмотря на колоссальное давление Запада. Об этом глава государства заявил в эксклюзивном интервью генеральному директору ТАСС Андрею Кондрашову.Читайте такжеЗапрет на импорт алмазов и контроль финансовых переводов. 12-й пакет санкций ЕС против РФ"Когда на Украине начался конфликт, я сказал, что не знаю, как будут развиваться события. И мы тогда приняли решение на государственном уровне осудить конфликт, так же как и все остальные, но мы сказали, что наша позиция - не вводить санкции [против РФ]. Я сказал это тогда, потому что мы знаем по себе, каково это, когда против вас вводят санкции. У нас есть дружественный нам народ, и было бы несправедливо поступать так с русским народом", - указал Вучич."Но я заявил сербам, что не могу этого гарантировать, потому что не знаю, каким будет в дальнейшем все это давление. Мне не хотелось играть героя один, два или три дня и потом менять свое решение. Но то, что я говорю: "Я не знаю", и когда я говорю, что не знаю, то это мое слово стоит больше, чем чье-либо твердое обещание", - отметил глава государства."Сейчас прошло ровно два года [с момента начала специальной военной операции]. Сербия - единственная страна в Европе, которая не ввела никаких санкций. У вас много друзей во всех странах Европы, и все они ввели санкции против России. Кто-то вам скажет, что их ввела центральная власть и они против этого, кто-то скажет, что мы против вас ввели санкции, но мы помогаем в других вопросах. Единственная страна, которая не ввела санкции - это маленькая Сербия", - подчеркнул Вучич, добавив, что на каждом мероприятии на международном уровне, где присутствует сербский лидер, "основная тема - это санкции против России"."Мы не бьем себя в грудь или что-то подобное, но, как видите, мой ответ вам и впредь будет таким, что мы будем стараться защищать свою позицию как можно дольше. Нам удается это делать уже два года. Продолжим ли мы это делать - не знаю, но надеюсь на это", - заключил глава государства.После начала специальной военной операции Вучич в обращении к нации по итогам заседания Совета безопасности Сербии сообщил, что его страна поддерживает территориальную целостность Украины, но не будет вводить санкции против РФ. Он заявил, что республика временно прекращает военные и полицейские учения со всеми зарубежными партнерами. Вучич отметил, что Сербия считает Россию и Украину братскими государствами и сожалеет о том, что происходит на востоке Европы. Также он сообщил, что Белград готов оказывать гуманитарную помощь Киеву.\nTags: Россия, Сербия, Санкции в отношении России, Вучич, Александар, Кондрашов, Андрей Олегович',
#        'В феврале 2024 года средние предлагаемые зарплаты пяти самых высокооплачиваемых профессий в России находятся в диапазоне от 103 до 152 тысяч рублей в месяц. Аналитики платформы «Авито Работа» проанализировали рынок труда и назвали специальности с самыми высокими заработками (исследование есть в распоряжении «Ленты.ру»).Возглавил рейтинг высокооплачиваемых сотрудников фрезеровщик — спрос работодателей на таких специалистов подскочил в феврале в 3,4 раза в годовом выражении. Средние зарплаты, предлагаемые соискателям с этой профессией при этом выросли почти вдвое, до 152 тысяч рублей в месяц. Больше всего фрезеровщикам готовы платить в Калужской области — от 180 до 230 тысяч рублей, при этом работнику готовы оплатить проживание и компенсировать средства, потраченные на дорогу до места работы.\nНа второй строчке в феврале оказалась профессия горного мастера — спрос на них вырос на 123 процента по сравнению с аналогичным месяцем прошлого года, а зарплатные ожидания на 41 процент, до 138,1 тысячи рублей в месяц. В тройку лидеров вошел также стоматолог, их востребованность выросла на 19 процентов, а средняя предлагаемая оплата труда на 25 процентов (до 136,2 тысячи рублей). При этом в Тюменской области такому врачу готовы предложить от 300 тысяч рублей в месяц при неполной занятости.На четвертой позиции среди профессий с самым большим доходом расположился брокер по недвижимости. Искать таких сотрудников работодатели стали в 2,4 раза чаще, а их зарплаты выросли на 12 процентов, в среднем до 128,1 тысячи рублей в месяц. При этом в Краснодарском крае готовы предложить до 150 до 375 тысяч в месяц начинающему специалисту, готовому пройти внутрикорпоративное обучение. Замыкает пятерку аналитик — число вакансий по этой профессии увеличилось более, чем в трое, а зарплаты выросли в среднем на 104 процента, до 103,1 тысячи рублей в месяц.Ранее президент России Владимир Путин оценил нехватку в стране рабочих рук. По его словам, российскому рынку труда не хватает порядка 2,5 миллиона человек. «Прямо сейчас строительный сектор, промышленность и так далее — прямо сейчас готовы сотнями тысяч (...) брать», — заявил он. По словам главы государства, для решения проблемы кадрового голода с помощью трудовых мигрантов нужно улучшить работу по их привлечению, добиться, чтобы они соблюдали законы и учили язык.',
#        'МОСКВА, 19 фев – ИП Голиков. Развитие интеллекта и расширение словарного запаса — важные аспекты личностного роста, которые могут быть достигнуты с помощью различных методов. Одним из наиболее эффективных способов является чтения книг, общение с умными людьми, а еще – практика интеллектуальных игр. О них и поговорим подробнее.\nИгры — не только приятное времяпрепровождение, но и отличный способ тренировки мозга. Рассмотрим несколько разновидностей таких игр и подумаем, как использовать их для своего развития.\nРешайте головоломки, кроссворды и судоку. Эти игры развивают логическое мышление и способствуют увеличению словарного запаса. Сюда же можно отнести вариации лексических игр, от "эрудита" до игры слова из букв, когда игроки составляют разные слова из букв заданного в начале раунда слова.\nИграйте в настольные игры, такие как шахматы или го. Это поможет развить стратегическое мышление и улучшит память. Добавим сюда разнообразные современные настольные игры, как для двоих, так и целой компании участников – от "монополии" до игр по мотивам популярных сериалов.\nСуществует множество мобильных приложений, предназначенных для тренировки мозга. Они предлагают разнообразные задания, направленные на развитие различных аспектов интеллекта. Многие приложения работают в интегративной или игровой форме. Есть и тематические сайты с интеллектуальными играми. Например, Makeword (Мэйкворд).\nУвеличение словарного запаса — ключевой элемент развития интеллекта. Выбирайте новые слова каждый день и старайтесь использовать их в повседневной речи. Это поможет закрепить их значение. Для этого используют все те же приложения или учат слова "по старинке", с помощью карточек.\nИзучение новых языков также способствует расширению словарного запаса. Попробуйте изучать слова на других языках, чтобы получить дополнительные выгоды для мозга. Поиск взаимосвязей между лексическими формами разных языков способствует и общему развитию, и развитию семантических навыков.\nИнтеллектуальные игры — это отличный способ развивать свой интеллект и расширять словарный запас. Систематическое чтение, решение головоломок и постоянное обучение новым словам создадут прочные основы для вашего интеллектуального роста.\nРеклама, ИП Голиков И.О., erid: 4CQwVszH9pWvp5b4MTk\nПартнерский материал. МИА "Россия сегодня" не несет ответственности за содержание материала. Товары и услуги подлежат обязательной сертификации.\nЗаявка на размещение пресс-релиза.',
#        'Глава движения «Патриоты» Филиппо призвал французов к\xa0свержению «клики» Макрона\nГлава французского движения «Патриоты» Флориан Филиппо призвал граждан страны свергнуть «клику» президента Эммануэля Макрона. Об этом со ссылкой на\xa0страницу политика в\xa0социальной сети X сообщает РИА Новости.\nПо словам Филиппо, спящему французскому народу необходимо срочно проснуться и выгнать властную клику, которая в\xa0интересах глобалистской олигархии превращает Францию в\xa0страну третьего мира.\nПолитик привел в\xa0качестве примера действий властей, направленных против интересов Франции, выделение €3 млрд помощи Украине, введение платы за\xa0дополнительную часть профессионального обучения и приглашение кубинских врачей во французские больницы.\nРанее лидер французского движения «Патриоты» Флориан Филиппо призвал всех желающих продолжения боевых действий на\xa0Украине, среди которых президент Франции Эммануэль Макрон, канцлер ФРГ Олаф Шольц и глава ЕК Урсула фон дер Ляйен, самим отправиться на\xa0фронт.\nРанее политолог оценил возможность прекращения дипломатических отношений России с\xa0ЕС.\nTags: Филиппо, Макрона, Францию, Украине, ФРГ, Олаф Шольц, Урсула фон дер Ляйен',
#        'Клинический психолог Станислав Самбурский рассказал о пользе делегирования для сохранения баланса между работой и личной жизнью. По его словам, нужно уметь передавать часть ответственности другим.\n«Большинству специалистов делегирование даётся с трудом: «Лучше медленнее, но зато сам точно всё сделаю, и не надо тратить время, чтобы рассказать и обучить». Однако, чтобы больше успевать, нужно уметь передавать часть ответственности другим людям, которые могут их быстрее выполнить», — заявил эксперт в беседе с Life.ru.По его словам, важно определить личные ценности и расставить приоритеты.Также рекомендуется зафиксировать временные промежутки, когда человек доступен по работе и для близких.Ранее вице-президент клуба молодых предпринимателей Росмолодёжи, член экспертного совета Госдумы по молодёжной политике и Ассоциации карьерных консультантов России Гарри Мурадян в беседе с НСН рассказал о новых трендах рынка труда.\nTags: В России, Новости России, Психология, Работа, Россия, Эксперт'],
#       dtype=object)

# %% [markdown]
# ##### **Above** we can see an interesting part in data, named **'Tags:'**
# Those Tags basically describing the topic well, but they look more like key words not the topic naming form.
# Lets keep in mind that we have a hint in text and continue to look in details.
#
#
# Explanation about topic modelling approaches, which we will not use and why:
#
# - LDA (Latent Dirichlet Allocation) algo described [here](https://medium.com/analytics-vidhya/text-classification-using-lda-35d5b98d4f05) which can do topic modelling on not-labelled data. It is simple to implement, works fast - but has significant disadvantages: it uses splitting text to n-grams which means we will lose context, it needs pre-defined count of categories (which we do not know exactly) and also it can mix categories between each other (like same top-words for several categories would be the same), so basically this solution will work but not percisely at all, that's why we know the approach existis but will go with another one.
# Even if we'll use only **Tags:** part for LDA, we can step in mixing categories trap.
#
# - frequency based key words detection (advantages and disadvantages almost sane same as for LDA)

# %%
# we can see html tags etc, so I will apply light text processing

def text_preprocessing(s):
    """
    - Remove "@name"
    - Remove other special characters
    - Remove trailing whitespace and \n \t
    """
    # Remove @name
    s = re.sub(r'(@.*?)[\s]', ' ', s)

    # Remove some special characters
    s = re.sub(r'([\;\:\|•«\n])', ' ', s)
    # Replace '&amp;' with '&'
    s = re.sub(r'&amp;', '&', s)
    # Remove trailing whitespace
    s = re.sub(r'\s+', ' ', s).strip()

    s = re.sub(r"http\S+", "", s)
    s = re.sub(r"^\n", "", s)

    for symb in ["!", ",", ":", ";", "?"]:
      s = re.sub(rf"\{symb}\.", symb, s)

    s = re.sub(r"#\S+", "", s)
    s = s.strip()

    return s

# %%
data['text'] = data['fullText'].apply(text_preprocessing)

# %%
# text started to look much more readable without not needed symbols
# also we can spot that overall format of the text is kind of news from different russian news sources

data['text'].sample(5).values
# Out:
# array(['СИМФЕРОПОЛЬ, 21 фев – РИА Новости. Депутат Госдумы от Севастополя, член комитета по международным делам Дмитрий Белик заявил, что Запад поставками дальнобойных ракет решил идти ва-банк в украинском конфликте, пытаясь оказать психологическое давление на Россию. Ранее осведомленный источник РИА Новости сообщил, что Запад потребовал от Киева предоставить перечень целей на территории России и обосновать целесообразность нанесения по ним ударов, а эксплуатацию и применение поставляемых Украине боевых ракет повышенной дальности - осуществлять под контролем натовских специалистов. "Сегодня Запад обеспокоен не за Украину, а за свои инвестиции, которые он туда вложил. Поэтому, судя по всему, западные кураторы решили пойти ва-банк, бросив на карту все, пытаясь оказать психологическое давление на Россию. Думаю, что на данном этапе вряд ли кто-то даст Украине оружие, способное поражать центр России", - сказал Белик РИА Новости. По его словам, выбор целей на территории России подразумевает уже участие Запада в военном конфликте, причем не опосредованное, а самое что ни на есть прямое. "Пришла пора отбросить ложные мысли о какой-то политической осторожности Запада в российско-украинском конфликте. Поставка дальнобойных ракет – это последний убедительный довод", - подчеркнул депутат. Ранее президент России Владимир Путин заявил, что демилитаризованная зона на Украине должна быть на таком удалении, которое бы обеспечило безопасность мирных городов России от обстрелов дальнобойного орудия, прежде всего, иностранного производства, которое украинские власти применяют для обстрела мирных городов.',
#        'За января 2024 года в адрес портов Азово-Черноморского бассейна на СКЖД направили 2 млн тонн грузов. Количество отправок выросло за счет увеличения погрузки нефти и нефтепродуктов на 12,1%, кокса на 76,9%, химикатов в 2,6 раза, а также цемента на 15,8%. Уже завершили ключевые этапе проекта, направленного на обновление и развитие ж/д инфраструктуры на подходах к портам АЧБ. В прошлом году модернизировали станцию Тихорецкая — крупнейший узел на пути к портам, сообщает пресс-служба СКЖД. Tags Азово-Черноморский бассейн, грузы, перевозки, порты, СКЖД',
#        'Политолог Межевич выборы в Литве не изменят отношения республики к России 19 февраля Литва переходит к следующему этапу подготовки к президентским выборам, которые должны пройти в республике в мае. Крайний срок регистрации участников истекает, и теперь претенденты должны внести избирательный залог почти в €9 тыс., чтобы продолжить участие в борьбе за пост главы государства. Всего в литовской избирательной кампании пять этапов кандидат заявляет о своем участии в выборах, платит взнос, подает (с 19 февраля по 8 марта) в ЦИК документы, в том числе краткую предвыборную программу, затем собирает (до 28 марта) как минимум 20 тыс. подписей избирателей, и наконец проходит регистрацию в рамках голосования (не позднее 11 апреля). Вести агитацию и встречаться с избирателями политики могут на протяжении всех этапов. В этот раз о желании баллотироваться в президенты республики заявили 11 человек. Глава государства Гитанас Науседа, премьер-министр Ингрида Шимоните, юрист Игнас Вегеле, врач Эдуардас Вайткус, бывший командующий армией страны Валдас Туткус, политик Зенонас Андруленас, экс-замгенсека НАТО Гедримас Еглинскас, вице-спикер парламента Андрюс Мазуронис, оппозиционный депутат Аурелиус Верига, бывший глава Конституционного суда Дайнюс Жалимас и парламентарий Ремигиюс Жемайтайтис, которого выгнали из собственной партии за антисемитские комментарии. Тройка сильнейших Согласно последним опросам, лидирует в предвыборной кампании Науседа. По исследованию Delfi, действующий президент набирает 23,5% голосов литовцев. Второе место занимает адвокат Вегеле с 12,2%. В начале 2000-х он возглавлял Литовскую партию христианских демократов, которая в настоящее время стала частью правящего Союза Отечества». Замыкает тройку лидеров премьер Шимоните с 10,9%. Пять лет назад она уже пыталась занять пост президента, но проиграла Науседе во втором туре голосования. Что касается остальных кандидатов, то все они набирает меньше 5% поддержки. Единственное исключение — лидер оппозиционных социал-демократов Вилия Блинкявичюте с 8,4% рейтинга. Однако политик отказалась выдвигать свою кандидатуру и поддержала Науседу. При этом 15,7% респондентов все еще не определись с тем, за кого будут голосовать, а 6,7% литовцев вообще не собираются участвовать в выборах. Как ожидается, президентская кампания, как и в большинстве парламентских республик, будет сосредоточена на внешнеполитических вопросах. По конституции Литвы, именно они входят в число компетенций главы государства, полномочия в других сферах сильно ограничены. Главной темой по внешнеполитическому треку в европейском регионе остается конфликт на Украине, в котором Вильнюс занимает сторону Киева, всячески критикуя Россию. Если брать мнение трех основных участников гонки по этому вопросу, то оно не сильно отличается. Науседа с начала СВО в феврале 2022 года призывает к помощи Киеву, в том числе военной, усилению сотрудничества с НАТО и давлению на Москву. Шимоните как премьер-министр эту линию поддерживает. В целом руководство Литвы допускает возможность урегулирования конфликта лишь на условиях» Украины. Юрист Вегеле же считает, что Киеву стоит начать думать о мире на фоне провалов на фронте и угрозы эскалации ситуации. При этом адвокат уверял, что поражения Украины допускать нельзя. Вегеле также критиковал Вильнюс за разрушение отношений с соседней Белоруссией, которую он назвал буфером между Литвой и Россией. Литва ориентируется на США Отношения России и Литвы пребывают не в лучшем состоянии уже не первый год. Катализатором изменений тут стала совсем не СВО — политические контакты между государствами заморожены еще с 2017 года. К 2024 году экономическое взаимодействие осложняется множественными санкциями, а дипломатические отношения сведены к минимуму. Опрошенные Газетой.Ru» эксперты сходятся на том, что все кандидаты в президенты Литвы в целом настроены антироссийски. По словам руководителя Центра белорусских исследований Института Европы РАН Николая Межевича, тут вряд ли стоит ждать каких-то изменен ...
#        'Собирать вместе старшеклассников со всего города на массовый бал в Арсеньеве давняя традиция. Кавалеры в костюмах, барышни в пышных нарядах. Подготовка к балу начинается с сентября. Желающих много. Большой зал спортивной школы Полет» в этом году вместил 126 старшеклассников. Вальс, падеграс, мазурка, кадриль. В светском обществе 19 века эти танцы были популярны. Но и сегодня школьники уверяют, часто себя ловят на мысли, что этикет позапрошлого века незаметно входит в их повседневную жизнь, особенно, если ребята участвуют в мероприятии не в первый раз. Алена Коломыцина, ученица 10 класса, считает, что погружение в историю, важно для любого человека. Родители после таких собраний открывают в детях что-то новое. Смеются, в речи современных ребят проскальзывают слова маменька», извольте», будьте любезны». По словам многих родителей, ребята меняются прямо на глазах. На таких балах юноши ближе знакомятся с девушками. Случалось, что дружеские чувства перерождались в более высокие, и спустя годы после школы создавались семьи. Атмосфера бала добавляет романтики, признаются участники. Но и обычное общение тоже важная часть мероприятия. В фотозонах - реквизит 19 века. Бал состоит из двух частей. В первой царит атмосфера 19 века. Во второй ведущие предлагают юношам и девушкам в бальных нарядах поучаствовать в танцевальных баттлах на современные музыкальные композиции. Школьный бал в Арсеньеве - благотворительное мероприятие. По словам организаторов, его главная задача - научить школьников делать добро. Собранные средства от продажи билетов в зрительном зале, после передают в детский дом. Вадим Перевалов, г. Арсеньев',
#        '29-летнего инспектора по досмотру службы авиационной безопасности Храброво» задержали за хранение наркотиков в багажнике автомобиля. Об этом в понедельник, 19 февраля, сообщает пресс-служба УМВД по Калининградской области. Сотрудники ГИБДД и отделения по контролю за оборотом наркотиков остановили Тойоту», которой управлял задержанный. Во время осмотра багажника они обнаружили тайник с наркотиками. Согласно заключению экспертно-криминалистического центра, в полиэтиленовом пакете были 9,7 грамма гашиша и 0,95 грамма соли». Водитель признался, что запрещенные вещества принадлежат ему – Возбуждено уголовное дело по ч. 1 ст. 228 УК РФ Незаконные приобретение, хранение, перевозка наркотических средств, психотропных веществ или их аналогов в значительном размере». Согласно санкциям статьи, мужчине грозит до трех лет лишения свободы. Автомобиль помещен на спецстоянку. Выясняются все обстоятельства произошедшего, – прокомментировали в УМВД. Ранее kaskad.tv писал, что в Калининграде осудили наркоторговца, который хранил запрещенное вещество в морозилке. Tags храброво, гашиш, соль, аэропорт храброво, новости, каскад, калининград'],
#       dtype=object)

# %%
# now let's check if all examples are written in russian language to get more precise understanding

from ftlangdetect import detect

def detect_language(text):
  doc = detect(text, low_memory=True)['lang']
  return doc

data['lang'] = data['text'].apply(detect_language)

# %%
data['lang'].value_counts()
# Out:
# ru     11956
# sah       54
# tt        44
# os        23
# mhr       14
# uk         4
# bg         2
# Name: lang, dtype: int64

# %%
# so here we can see that mostly texts are in russian with a bit of other languages like 'sah', 'tt' etc.
# non-russian texts cover approx 1% of data
# approach we will use for modeling has a possibility to handle multilingual cases so we'll keep those texts for now

data[data['lang'] == 'sah']
# Out:
#                                                 fullText     pubTime  \
# 3504   Амма сэлиэнньэтигэр «Тэтим» түөлбэ күнүн бэлиэ...  2024-02-19
# 3505   Сунтаар улууһун Тойбохой нэһилиэгэр хорсун буо...  2024-02-19
# 3506   Бырабыыталыстыба сыллааҕы үлэтин отчуота Сунта...  2024-02-19
# 3507   Москватааҕы доруобуйа харыстабылын департамены...  2024-02-19
# 3508   Кыһыл хаалтыс доҕордоох,\nГорн, барабаан аргыс...  2024-02-19
# 3509   Горнай улууһугар өрөспүүбүлүкэтээҕи литературн...  2024-02-19
# 3510   Мэҥэ Хаҥалас Төҥүлүтүгэр баар “Нал” кафе салай...  2024-02-19
# 3511   Олунньу 19 күнүгэр М.Е. Николаев аатынан Өрөсп...  2024-02-19
# 3512   Биэриигэ хоһоонньутар уонна ырыа толороооччула...  2024-02-19
# 3513   Дьокуускайга өрөспүүбүлүкэҕэ олорор норуоттар ...  2024-02-19
# 3514   Саха сирин боксера Василий Егоров «Бэрэсидьиэн...  2024-02-19
# 3515   Ас бырааһынньыгын ситиһиилэрин уонна биһиги ас...  2024-02-19
# 3516   Сунтаар улууһун Уһун Күөл нэһилиэгэр дьиэ кэрг...  2024-02-19
# 3517   Арктикатааҕы судаарыстыбаннай култуура уонна и...  2024-02-19
# 3518   Виртуоз-скрипач, норуоттар икки ардыларынааҕы ...  2024-02-19
# 3519   Россия бэрэсидьиэнэ Владимир Путин итэҕэллээҕэ...  2024-02-19
# 3520   Олунньу 18 күнүгэр Горнай улууһун киинигэр Бэр...  2024-02-19
# 3521   РФ бэрэсидьиэнэ Владимир Путин итэҕэллээҕэ Мар...  2024-02-19
# 3522   Муосчут Денис биир күн асчыт идэтигэр бэйэтин ...  2024-02-19
# 3523   «Алданнааҕы оройуоннай киин балыыһа кэллэктииб...  2024-02-19
# 3524   Бүгүн, олунньу 19 күнүгэр, Ил Дархан Айсен Ник...  2024-02-19
# 7535   Таатта улууһун киинигэр Ытык Күөлгэ «Хаарбах д...  2024-02-20
# 7536   СӨ бырабыыталыстыбатын бэрэссэдээтэлин бастакы...  2024-02-20
# 7537   Бүлүү улууһун Тыымпы нэһилиэгин Иннокентий Бор...  2024-02-20
# 7538   Тылы-өһү сайыннарыы улахан суолталаах. Төрүт к...  2024-02-20
# 7539   Сунтаар улууһугар Виктор Николаев – Хотой Биик...  2024-02-20
# 7540   Дьокуускай куоракка медицина эдэр исписэлиистэ...  2024-02-20
# 7541   Чурапчы улууһугар үтүө үгэскэ кубулуйбут Аҕа д...  2024-02-20
# 7542   Бүлүү улууһун 2-с Күүлэт нэһилиэгэр анал байыа...  2024-02-20
# 7543   Бэрэсидьиэн Владимир Путин 2024 сылы Дьиэ кэрг...  2024-02-20
# 7544   Ф.И. Авдеева аатынан оҕо айымньытын дыбарыаһын...  2024-02-20
# 7545   Өрөспүүбүлүкэтээҕи остуол тиэнньиһин күрэҕэ Мы...  2024-02-20
# 7546   Тааттаттан анал байыаннай дьайыыга ыҥырыллан, ...  2024-02-20
# 7547   Дьокуускайга саҥа арыллыбыт онко киин сүрүн бы...  2024-02-20
# 7548   Украина аармыйата сэбэ-сэбиргэлэ тиийбэт буола...  2024-02-20
# 7549   Уус Алдаҥҥа ордук олох-дьаһах коммунальнай хаһ...  2024-02-20
# 7550   Олох-дьаһах коммунальнай өҥөлөрүн төлүүр табыг...  2024-02-20
# 7551   Олунньу 20 күнүгэр Саха сирин Ил Дархана Айсен...  2024-02-20
# 7552   Олунньу 29 күнүгэр Россия бэрэсидьиэнэ Владими...  2024-02-20
# 11569  Хаҥалас улууһун Өктөм сэлиэнньэтигэр РФ Бэрэси...  2024-02-21
# 11570  Россия бырабыыталыстыбатын бэрэссэдээтэлин сол...  2024-02-21
# 11571  Горнай улууһун олохтооҕо 46 сыл ыстаастаах «Кр...  2024-02-21
# 11572  Ньурба улууһугар Саха Өрөспүүбүлүкэтин ситэрии...  2024-02-21
# 11573  Бүгүн, олунньу 21 күнүгэр, Аммаҕа Аҕа Дойдуну ...  2024-02-21
# 11574  Олунньу 27 күнүгэр бүтүн Россиятааҕы «Всей сем...  2024-02-21
# 11575  Ил Дархан Айсен Николаев сорудаҕынан Саха сирэ...  2024-02-21
# 11576  Оҕоҕо хотугу дойду кыылларын хамсаныылаах оонн...  2024-02-21
# 11577  Киин куоракка бэрэсидьиэн Владимир Путин итэҕэ...  2024-02-21
# 11578  Дьокуускай куорат «Лена» киинэ тыйаатырыгар бэ...  2024-02-21
# 11579  Ньурба улууһугар Саха Өрөспүүбүлүкэтин ситэрии...  2024-02-21
# 11580  Россия худуоһунньуктарын сойууһун чилиэнэ үлэт...  2024-02-21
# 11581  Быйыл үөрэххэ туттарсар оҕолорго уонна кинилэр...  2024-02-21
# 11582  Биэриигэ тыа хаһаайыстыбатын учуонайдара үүнээ...  2024-02-21
# 11583  Уһуйааҥҥа араас хабааннаах үлэ ыытыллар. Чуола...  2024-02-21
#
#                                                     text lang
# 3504   Амма сэлиэнньэтигэр Тэтим» түөлбэ күнүн бэлиэт...  sah
# 3505   Сунтаар улууһун Тойбохой нэһилиэгэр хорсун буо...  sah
# 3506   Бырабыыталыстыба сыллааҕы үлэтин отчуота Сунта...  sah
# 3507   Москватааҕы доруобуйа харыстабылын департамены...  sah
# 3508   Кыһыл хаалтыс доҕордоох, Горн, барабаан аргыст...  sah
# 3509   Горнай улууһугар өрөспүүбүлүкэтээҕи литературн...  sah
# 3510   Мэҥэ Хаҥалас Төҥүлүтүгэр баар “Нал” кафе салай...  sah
# 3511   Олунньу 19 күнүгэр М.Е. Николаев аатынан Өрөсп...  sah
# 3512   Биэриигэ хоһоонньутар уонна ырыа толороооччула...  sah
# 3513   Дьокуускайга өрөспүүбүлүкэҕэ олорор норуоттар ...  sah
# 3514   Саха сирин боксера Василий Егоров Бэрэсидьиэнн...  sah
# 3515   Ас бырааһынньыгын ситиһиилэрин уонна биһиги ас...  sah
# 3516   Сунтаар улууһун Уһун Күөл нэһилиэгэр дьиэ кэрг...  sah
# 3517   Арктикатааҕы судаарыстыбаннай култуура уонна и...  sah
# 3518   Виртуоз-скрипач, норуоттар икки ардыларынааҕы ...  sah
# 3519   Россия бэрэсидьиэнэ Владимир Путин итэҕэллээҕэ...  sah
# 3520   Олунньу 18 күнүгэр Горнай улууһун киинигэр Бэр...  sah
# 3521   РФ бэрэсидьиэнэ Владимир Путин итэҕэллээҕэ Мар...  sah
# 3522   Муосчут Денис биир күн асчыт идэтигэр бэйэтин ...  sah
# 3523   Алданнааҕы оройуоннай киин балыыһа кэллэктииби...  sah
# 3524   Бүгүн, олунньу 19 күнүгэр, Ил Дархан Айсен Ник...  sah
# 7535   Таатта улууһун киинигэр Ытык Күөлгэ Хаарбах дь...  sah
# 7536   СӨ бырабыыталыстыбатын бэрэссэдээтэлин бастакы...  sah
# 7537   Бүлүү улууһун Тыымпы нэһилиэгин Иннокентий Бор...  sah
# 7538   Тылы-өһү сайыннарыы улахан суолталаах. Төрүт к...  sah
# 7539   Сунтаар улууһугар Виктор Николаев – Хотой Биик...  sah
# 7540   Дьокуускай куоракка медицина эдэр исписэлиистэ...  sah
# 7541   Чурапчы улууһугар үтүө үгэскэ кубулуйбут Аҕа д...  sah
# 7542   Бүлүү улууһун 2-с Күүлэт нэһилиэгэр анал байыа...  sah
# 7543   Бэрэсидьиэн Владимир Путин 2024 сылы Дьиэ кэрг...  sah
# 7544   Ф.И. Авдеева аатынан оҕо айымньытын дыбарыаһын...  sah
# 7545   Өрөспүүбүлүкэтээҕи остуол тиэнньиһин күрэҕэ Мы...  sah
# 7546   Тааттаттан анал байыаннай дьайыыга ыҥырыллан, ...  sah
# 7547   Дьокуускайга саҥа арыллыбыт онко киин сүрүн бы...  sah
# 7548   Украина аармыйата сэбэ-сэбиргэлэ тиийбэт буола...  sah
# 7549   Уус Алдаҥҥа ордук олох-дьаһах коммунальнай хаһ...  sah
# 7550   Олох-дьаһах коммунальнай өҥөлөрүн төлүүр табыг...  sah
# 7551   Олунньу 20 күнүгэр Саха сирин Ил Дархана Айсен...  sah
# 7552   Олунньу 29 күнүгэр Россия бэрэсидьиэнэ Владими...  sah
# 11569  Хаҥалас улууһун Өктөм сэлиэнньэтигэр РФ Бэрэси...  sah
# 11570  Россия бырабыыталыстыбатын бэрэссэдээтэлин сол...  sah
# 11571  Горнай улууһун олохтооҕо 46 сыл ыстаастаах Кре...  sah
# 11572  Ньурба улууһугар Саха Өрөспүүбүлүкэтин ситэрии...  sah
# 11573  Бүгүн, олунньу 21 күнүгэр, Аммаҕа Аҕа Дойдуну ...  sah
# 11574  Олунньу 27 күнүгэр бүтүн Россиятааҕы Всей семь...  sah
# 11575  Ил Дархан Айсен Николаев сорудаҕынан Саха сирэ...  sah
# 11576  Оҕоҕо хотугу дойду кыылларын хамсаныылаах оонн...  sah
# 11577  Киин куоракка бэрэсидьиэн Владимир Путин итэҕэ...  sah
# 11578  Дьокуускай куорат Лена» киинэ тыйаатырыгар бэҕ...  sah
# 11579  Ньурба улууһугар Саха Өрөспүүбүлүкэтин ситэрии...  sah
# 11580  Россия худуоһунньуктарын сойууһун чилиэнэ үлэт...  sah
# 11581  Быйыл үөрэххэ туттарсар оҕолорго уонна кинилэр...  sah
# 11582  Биэриигэ тыа хаһаайыстыбатын учуонайдара үүнээ...  sah
# 11583  Уһуйааҥҥа араас хабааннаах үлэ ыытыллар. Чуола...  sah

# %% [markdown]
# # Modeling

# %% [markdown]
# **Approach**
#
# > Step 1: Label data using Gemini Pro
#
# 1.   Prompt construction
# 2.   Code run, save the data
#
#
# > Step 2: Analyse and group received labels
#
# > Step 3: Split data to train and test, fine-tune transformer model to detect topic on any kind of new text

# %% [markdown]
# ### Gemini Pro labeling

# %%
# # I used Gemini Pro to label initial data with following prompt:


# PROMPT = """" Как специалист по медийному пространству и журналист, классифицируй поданный текст одной категорией,
#                     которая будет включать основную тему или нарратив,
#                     категория является тематикой текста и должна состоять из от 1 до 3 слов.
#                     Обрати внимание, что тексты являются новостными статьями либо сообщениями новостного характера, категоризируй
#                     учитывая этот факт.


#         Классифицируй поданный текст по определениию выше и возврати категорию для него:
#         """


# data['predicted_by_gemini'] = gemini_predictions

# %%
data_with_gemini = pd.read_csv('/content/test_data_gemini_labeled.csv')

# %%
data_with_gemini.head()
# Out:
#                                             fullText     pubTime  \
# 0  Бабушкинский суд столицы приговорил трех актив...  2024-02-19
# 1  Бывшего совладельца сетей "Кофе хауз" и "Азбук...  2024-02-19
# 2  Ежегодный фестиваль исторических садов пройдет...  2024-02-19
# 3  На улицах Москвы появилось свыше 120 светоотра...  2024-02-19
# 4  Три дома, в которых в свое время жили сотрудни...  2024-02-19
#
#          predicted_by_gemini
# 0               происшествия
# 1              мошенничество
# 2  садово-парковое искусство
# 3   городская инфраструктура
# 4              ремонт зданий

# %%
# here we can see the output received from Gemini, topics are already formulated well, but
# together with it Gemini failes to 'safety error on 3822 examples of data, howewer
# even labeled dataset shoud be enough to go further

data_with_gemini['predicted_by_gemini'].value_counts().reset_index().iloc[0:40]
# Out:
#                                 index  predicted_by_gemini
# 0                  undefined category                 3822
# 1                    военные действия                  381
# 2                    военная операция                  275
# 3                            культура                  149
# 4                              погода                  139
# 5                              выборы                  127
# 6                         геополитика                  109
# 7                     здравоохранение                   98
# 8                                 дтп                   94
# 9                       мошенничество                   92
# 10                           здоровье                   89
# 11                     военная помощь                   80
# 12                       происшествия                   72
# 13                         шоу-бизнес                   70
# 14                    военная техника                   69
# 15                       спецоперация                   67
# 16            международные отношения                   67
# 17                    благоустройство                   63
# 18                          трансферы                   63
# 19                     прогноз погоды                   60
# 20                   внешняя политика                   59
# 21                 сельское хозяйство                   57
# 22                       происшествие                   52
# 23               криминальная хроника                   50
# 24                   военная ситуация                   46
# 25               военные преступления                   44
# 26                  городские новости                   42
# 27                           некролог                   42
# 28                гуманитарная помощь                   41
# 29                            новости                   40
# 30                        рынок труда                   40
# 31                    банковское дело                   39
# 32                   фигурное катание                   39
# 33                      поддержка сво                   37
# 34                     инфраструктура                   37
# 35  дорожно-транспортное происшествие                   37
# 36             государственная измена                   35
# 37                      строительство                   34
# 38          патриотическое воспитание                   34
# 39                  кибербезопасность                   32

# %%
# let's check if data match to the labeled topic
data_with_gemini[data_with_gemini['predicted_by_gemini'] == 'военные действия']['fullText'].sample(3).values
# Out:
# array(['Воздушная тревога объявлена на\xa0всей территории Украины\nВоздушная тревога объявлена на\xa0всей территории Украины. Информация о\xa0этом появилась на\xa0официальном украинском ресурсе для\xa0оповещения.\nПо данным сервиса, первые сирены прозвучали в\xa012:11 по\xa0местному времени (13:11 мск) в\xa0Киеве. Через\xa0четыре минуты красная зона распространилась на\xa0все регионы страны.\nВ ночь на\xa021 февраля на\xa0Украине сообщили о\xa0взрывах в\xa0подконтрольном Киеву Херсоне. До\xa0этого звуки взрывов также раздались в\xa0городе Чугуев в\xa0Харьковской области Украины.\n19 февраля сообщалось о\xa0серии взрывов в\xa0украинских городах Полтава и Кропивницкий. На\xa0всей территории Украины была объявлена воздушная тревога.\nВооруженные силы России стали наносить удары по\xa0украинской инфраструктуре с\xa010 октября 2022\xa0года — через\xa0два дня после теракта на\xa0Крымском мосту, за\xa0которым, по\xa0заявлению российских властей, стоят спецслужбы Украины. Атаки производятся по\xa0объектам в\xa0сфере энергетики, оборонной промышленности, военного управления и связи по\xa0всей стране. С\xa0тех пор воздушная тревога объявляется ежедневно в\xa0различных регионах Украины, иногда даже на\xa0всей территории страны.\nРанее глава МИД Украины Кулеба заявил, что не понимает, какие условия нужно выполнить Киеву для\xa0вступления в\xa0НАТО.\nTags: Украины, Киеве, Херсоне, России',
#        'Губернатор Брянской области Александр Богомаз заявил, что над территорией региона уничтожили беспилотный летательный аппарат (БПЛА) самолетного типа. Об этом он написал в своем Telegram-канале.Богомаз уточнил, что системы противовоздушной обороны (ПВО) сбили беспилотник над Клинцовским районом Брянской области. В результате инцидента пострадавших и разрушений нет. На месте происшествия работают оперативные и экстренные службы.',
#        'Российские военнослужащие перехватили беспилотник Вооруженных сил Украины (ВСУ) в небе над Брянской областью. Об этом сообщило Минобороны России в Telegram.Аппарат сбили около 8:00 по московскому времени. Целью дрона было совершение террористической атаки по расположенным на территории России объектам, подчеркнули в военном ведомстве.Уничтоженное устройство является беспилотником самолетного типа. Такие аппараты способны нести до нескольких десятков килограммов взрывчатки, они таранят цель, вызывая взрыв боевой части.В это же время еще один беспилотник ВСУ был сбит над Калужской областью. По данным главы региона Владислава Шапши, в результате инцидента никто не пострадал, разрушений нет.'],
#       dtype=object)

# %%
# let's check if data match to the labeled topic
data_with_gemini[data_with_gemini['predicted_by_gemini'] == 'фигурное катание']['fullText'].sample(3).values
# Out:
# array(['Тарасова заявила, что Skate Canada будет переманивать российских фигуристов\nЗаслуженный тренер СССР Татьяна Тарасова призвала не отвлекаться на\xa0инициативу Федерации фигурного катания Канады (Skate Canada), которая хочет добиться упрощения процедуры смены спортивного гражданства для\xa0фигуристов. Ее слова передает Sport24.\nSkate Canada уже внесла этот вопрос в\xa0предварительную повестку конгресса Международного союза конькобежцев (ISU), который пройдет 10–14 июня в\xa0Лас-Вегасе.\n«Эта инициатива позволит нашим спортсменам выступать не только за\xa0Канаду, а за\xa0любую другую страну. Пускай они подают свое предложение в\xa0ISU. Это их право, и не имеет никого значения, будут наши фигуристы менять спортивное гражданство или нет. Да, очередные нападки, но я бы никак не стала на\xa0это реагировать.\nНужно ждать, когда нас вернут соревнования, а не отвлекаться на\xa0это. С\xa0нашим мнением никто не считается! И в\xa0этом нет ничего хорошего. Своих спортсменов не хватает, будут пользоваться чужими. Так было, и так есть сейчас!» — заявила Тарасова.\nВ конце февраля 2022\xa0года Международный олимпийский комитет (МОК) выступил с\xa0обращением в\xa0адрес международных спортивных федераций и рекомендовал им не пускать отечественных и белорусских атлетов к\xa0любым соревнованиям.\nТак, Международный союз конькобежцев отстранил российских и белорусских атлетов от соревнований. На\xa0заседании ISU, которое прошло в\xa0октябре, вопрос о\xa0возвращении российских спортсменов не поднимался, несмотря на\xa0то, что был в\xa0повестке.\nРанее назвали лучшую фигуристку России.\nTags: Тарасова, Канады',
#        'Косторная заявила, что в\xa0группе Тутберидзе ее считали хамкой\nРоссийская фигуристка Алена Косторная в\xa0интервью на\xa0YouTube-канале Ляйсан Утяшевой рассказала, как проходило ее расставание с\xa0группой Этери Тутберидзе.\n«Прошел чемпионат России, уже Олимпиада, мне сняли гипс. Я выхожу на\xa0лед, третий день — ломаю левую руку. Загипсовали, через\xa0три-четыре дня выхожу на\xa0лед, и в\xa0конце тренировки тренеры мне сообщают: «Ты поломанная-переломанная, работать не хочешь, не желаешь, нас ни во что не ставишь, мы с\xa0тобой больше работать не будем», — сказала Косторная.\nКосторная работала с\xa0Этери Тутберидзе до\xa0середины 2020\xa0года, а затем ушла к\xa0Плющенко. Весной 2021\xa0года вернулась в\xa0«Хрустальный» с\xa0условием два месяца быть на\xa0испытательном сроке. Через\xa0год Косторная снова ушла от Тутберидзе, на\xa0этот раз к\xa0Елене Буяновой.\nВ начале 2023\xa0года бывший тренер Косторной объявила, что фигуристка ушла в\xa0парное катание. С\xa0осени 2022\xa0года она катается в\xa0паре с\xa0Георгием Куницей под\xa0руководством Сергея Рослякова.\nВ сентябре пара впервые выступила вместе на\xa0контрольных прокатах сборной России. Свою первую произвольную программу они поставили под\xa0саундтрек к\xa0фильму «Голодные игры».\nРанее бывшего возлюбленного Трусовой назвали открытием Спартакиады.\nTags: Косторная, Тутберидзе, России, Елене Буяновой, Георгием Куницей, Сергея Рослякова, сборной России',
#        'Министр спорта Татарстана Владимир Леонов подтвердил, что запуск проекта планируется в течении года. В настоящее время Алина Загитова занимается поиском тренера для школы.\n"Алина больше спортсменка, а не тренер. Она не будет тренировать, а станет генеральным менеджером школы. Сейчас Алина занимается поиском тренеров для школы, набирает команду. Мы постоянно находимся на связи. Объект планируется сдать и запустить в текущем календарном году", – приводит слова Владимира Леонова РИА Новости.\nНа Олимпийский играх 2018 года Алина Загитова стала чемпионкой в одиночном катании и серебряным призером в командном турнире фигуристов. Также она становилась чемпионкой мира в 2019 году и чемпионкой Европы 2018 года.'],
#       dtype=object)

# %%
# it looks like labels are quite percise in the current version, so we can continue with th approach
# let's take a look how many topics we detected so far

# %%
len(data_with_gemini['predicted_by_gemini'].unique())
# Out:
# 2193

# %% [markdown]
# #### Matching subtopics into topic
# Looks like topic are very sparse, we will try to match simular ones into 1 topic before fine-tuning

# %%
def assign_ids(text_column):
    # Convert text column to a pandas Series
    series = pd.Series(text_column)

    # Create a dictionary to store text values and their corresponding IDs
    text_to_id = {}

    # Initialize ID counter
    current_id = 1

    # Iterate over each text value in the Series
    for text in series:
        # Check if the text value already exists in the dictionary
        if text not in text_to_id:
            # If not, assign a new ID to the text value
            text_to_id[text] = current_id
            current_id += 1

    # Create a new Series to store the IDs corresponding to each text value
    ids = series.map(text_to_id)

    return ids

# %%
topics_df = data_with_gemini['predicted_by_gemini'].value_counts().reset_index()

# assign id to the predicted_by_gemini column
topics_df['id'] = assign_ids(topics_df['index'])

# %%
topics_df = topics_df[topics_df['index'] != 'undefined category']
topics_df = topics_df.rename({'index': 'topic', 'predicted_by_gemini': 'count'}, axis = 1)

# %%
# now we see the prevalance of topics initially labeled by Gemini
percs = data_with_gemini['predicted_by_gemini'].value_counts(normalize=True).reset_index()
percs = percs[percs['index'] != 'undefined category']
percs = percs.rename({'predicted_by_gemini': 'percentage'}, axis = 1)
percs = percs.drop('index', axis = 1)

pd.concat([topics_df,percs], axis=1)
# Out:
#                         topic  count    id  percentage
# 1            военные действия    381     2    0.031495
# 2            военная операция    275     3    0.022733
# 3                    культура    149     4    0.012317
# 4                      погода    139     5    0.011490
# 5                      выборы    127     6    0.010498
# ...                       ...    ...   ...         ...
# 2188    планирование парковок      1  2189    0.000083
# 2189    падения знаменитостей      1  2190    0.000083
# 2190  ветеранские организации      1  2191    0.000083
# 2191      приюты для животных      1  2192    0.000083
# 2192     пищевая безопасность      1  2193    0.000083
#
# [2192 rows x 4 columns]

# %%
! pip install sentence_transformers

# %%
## now we are going to make topic less sparse and combine simular ones into one using
## CLIP model as encoder, cosine simularity as simularity metric and with assumption that there
## must be not more than 250 topics

# %%
from sklearn.metrics.pairwise import cosine_similarity
from sentence_transformers import SentenceTransformer
from sklearn.cluster import KMeans
import torch


def map_topics(topics_df):
    # Load pre-trained CLIP model for text
    device = "cuda" if torch.cuda.is_available() else "cpu"
    encoder = SentenceTransformer('clip-ViT-B-32', device = device)

    # Encode subtopic names into embeddings
    embeddings = []
    for topic in topics_df['topic']:
      embedding_for_topic =  encoder.encode(topic, device = device, convert_to_tensor = False)
      embeddings.append(embedding_for_topic)


    # Calculate pairwise cosine similarity between embeddings
    similarities = cosine_similarity(embeddings)

    # Apply KMeans clustering
    kmeans = KMeans(n_clusters=250)
    clusters = kmeans.fit_predict(similarities)

    # Mapping topic ids to clusters
    topics_df['cluster'] = clusters


    return topics_df

# %%
df = map_topics(topics_df)

# %%
# so now we have 250 topics instead of 2k sparse ones, lets take a look at few of them
df[df['cluster'] == 94]
# Out:
#                     topic  count    id  cluster
# 2        военная операция    275     3       94
# 59       военный конфликт     22    60       94
# 161      военная разведка      8   162       94
# 191    военные технологии      6   192       94
# 208       военная история      6   209       94
# 209   военная мобилизация      6   210       94
# 293        военные потери      4   294       94
# 348        военные учения      4   349       94
# 364    военная технология      4   365       94
# 447      военная медицина      3   448       94
# 685        военные сводки      2   686       94
# 719        военная угроза      2   720       94
# 1068       военная поэзия      1  1069       94
# 1094       военная миссия      1  1095       94
# 1326       военные льготы      1  1327       94
# 1634      военные события      1  1635       94
# 1802      военные подвиги      1  1803       94
# 1945   военное воспитание      1  1946       94

# %%
df[df['cluster'] == 2]
# Out:
#                        topic  count    id  cluster
# 510    военно-морская миссия      3   511        2
# 1018  военно-спортивные игры      1  1019        2
# 1105   военно-морские учения      1  1106        2
# 1356     военно-морской флот      1  1357        2

# %%
df[df['cluster'] == 13]
# Out:
#                         topic  count    id  cluster
# 108                 реновация     11   109       13
# 416               реставрация      3   417       13
# 417          развитие региона      3   418       13
# 829   отмена масочного режима      1   830       13
# 967         реновация лагерей      1   968       13
# 1455      регистрация в отеле      1  1456       13
# 1835      реорганизация аптек      1  1836       13
# 2054    международные финансы      1  2055       13

# %%
df[df['cluster'] == 249]
# Out:
#                             topic  count    id  cluster
# 618             налоговые новости      2   619      249
# 675           награды и признание      2   676      249
# 699               налогообложение      2   700      249
# 770               налоговый вычет      2   771      249
# 974                 анализ данных      1   975      249
# 1019             налоговые льготы      1  1020      249
# 1133        назначение чиновников      1  1134      249
# 1394  ненадлежащее оказание услуг      1  1395      249
# 1670          налоговые нарушения      1  1671      249

# %%
## ok, so clustering works good, alhought some level of mistakes is presented
## I suggest, in real-life project to do this kind of mapping semi-manually
## first step is automatic clustering and second step is manual recheck and corrections
## now lets name the cluster by top-topic (by prevalence) name

# Finding the most popular topic in each cluster
top_topics = df.groupby('cluster').apply(lambda x: x.loc[x['count'].idxmax()]).reset_index(drop=True)

# Creating a dictionary for mapping subtopics to grouped topics
cluster_new_names = []
for _, row in df.iterrows():
    cluster = row['cluster']
    topic = top_topics[top_topics['cluster'] == cluster]['topic'].iloc[0]
    cluster_new_names.append(topic)

# %%
df['cluster_name'] = cluster_new_names

# %%
df.sample(5)
# Out:
#                           topic  count    id  cluster         cluster_name
# 68           военная подготовка     19    69       39       военная помощь
# 2073     арктические технологии      1  2074      184     телекоммуникации
# 611         финансовые проблемы      2   612      230    финансовая помощь
# 1463           травма музыканта      1  1464       32            праздники
# 299   железнодорожный транспорт      4   300      171  театральные новости

# %%
# top-topic by prevalence
df.groupby('cluster_name').sum()['count'].reset_index().sort_values(by='count', ascending=False).iloc[0:20]
# Out:
# <ipython-input-137-f87c2addc7cc>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   df.groupby('cluster_name').sum()['count'].reset_index().sort_values(by='count', ascending=False).iloc[0:20]
#                cluster_name  count
# 36         военные действия    509
# 31         военная операция    348
# 81          здравоохранение    299
# 42              геополитика    237
# 40                   выборы    190
# 163                  погода    165
# 112                культура    157
# 132           мошенничество    156
# 32           военная помощь    142
# 206      сельское хозяйство    132
# 22          благоустройство    118
# 9           банковское дело    107
# 78                 здоровье    106
# 63                      дтп    104
# 110    криминальная хроника    103
# 49   государственная измена    100
# 188            происшествия     99
# 93        кибербезопасность     97
# 34          военная техника     97
# 139                 новости     97

# %% [markdown]
# ### Preparation for fine-tunning and fine-tunning
#
# We do fine-tuning on prepared data which are already with topics to be able to predict topic on new data without Gemini usage anymore but with our own proprietary model, which would be much cheaper by costs.

# %%
data_with_gemini['text'] = data_with_gemini['fullText'].apply(text_preprocessing)

# %%
data_with_gemini
# Out:
#                                                 fullText     pubTime  \
# 0      Бабушкинский суд столицы приговорил трех актив...  2024-02-19
# 1      Бывшего совладельца сетей "Кофе хауз" и "Азбук...  2024-02-19
# 2      Ежегодный фестиваль исторических садов пройдет...  2024-02-19
# 3      На улицах Москвы появилось свыше 120 светоотра...  2024-02-19
# 4      Три дома, в которых в свое время жили сотрудни...  2024-02-19
# ...                                                  ...         ...
# 12092  Активный отдых должен быть комфортным. Костром...  2024-02-21
# 12093  Возможность вырастить свой урожай при поддержк...  2024-02-21
# 12094  Городской цирк костромичи выбрали во время онл...  2024-02-21
# 12095  Для комфортного и безопасного образования. В ш...  2024-02-21
# 12096  В мэрию областного центра начали поступать жал...  2024-02-21
#
#              predicted_by_gemini  \
# 0                   происшествия
# 1                  мошенничество
# 2      садово-парковое искусство
# 3       городская инфраструктура
# 4                  ремонт зданий
# ...                          ...
# 12092            благоустройство
# 12093         сельское хозяйство
# 12094            городская среда
# 12095         undefined category
# 12096        коммунальные услуги
#
#                                                     text
# 0      Бабушкинский суд столицы приговорил трех актив...
# 1      Бывшего совладельца сетей "Кофе хауз" и "Азбук...
# 2      Ежегодный фестиваль исторических садов пройдет...
# 3      На улицах Москвы появилось свыше 120 светоотра...
# 4      Три дома, в которых в свое время жили сотрудни...
# ...                                                  ...
# 12092  Активный отдых должен быть комфортным. Костром...
# 12093  Возможность вырастить свой урожай при поддержк...
# 12094  Городской цирк костромичи выбрали во время онл...
# 12095  Для комфортного и безопасного образования. В ш...
# 12096  В мэрию областного центра начали поступать жал...
#
# [12097 rows x 4 columns]

# %%
# adding 250 groupped topics to data
c = ['topic', 'cluster_name']

data_with_gemini = data_with_gemini.merge(df[c], left_on = 'predicted_by_gemini', right_on = 'topic', how = 'left')

# %%
# now we have everything we need - cleaned text and assingned topics names (cluster_name)

data_with_gemini.head()
# Out:
#                                             fullText     pubTime  \
# 0  Бабушкинский суд столицы приговорил трех актив...  2024-02-19
# 1  Бывшего совладельца сетей "Кофе хауз" и "Азбук...  2024-02-19
# 2  Ежегодный фестиваль исторических садов пройдет...  2024-02-19
# 3  На улицах Москвы появилось свыше 120 светоотра...  2024-02-19
# 4  Три дома, в которых в свое время жили сотрудни...  2024-02-19
#
#          predicted_by_gemini  \
# 0               происшествия
# 1              мошенничество
# 2  садово-парковое искусство
# 3   городская инфраструктура
# 4              ремонт зданий
#
#                                                 text  \
# 0  Бабушкинский суд столицы приговорил трех актив...
# 1  Бывшего совладельца сетей "Кофе хауз" и "Азбук...
# 2  Ежегодный фестиваль исторических садов пройдет...
# 3  На улицах Москвы появилось свыше 120 светоотра...
# 4  Три дома, в которых в свое время жили сотрудни...
#
#                        topic                    cluster_name
# 0               происшествия                    происшествия
# 1              мошенничество                   мошенничество
# 2  садово-парковое искусство  поисково-спасательная операция
# 3   городская инфраструктура        городская инфраструктура
# 4              ремонт зданий                        некролог

# %%
data_with_gemini.to_csv('test_data_to_transformer.csv')

# %%
data_with_gemini = pd.read_csv('test_data_to_transformer.csv')

# %% [markdown]
# #### Preprocess labels to be used as input to XLM_ROBERTA_MODEL

# %%
# filter from train data those examples where Gemini didn't returned a topic

data_for_training = data_with_gemini[~data_with_gemini.topic.isna()]

# %%
data_for_training.head()
# Out:
#    Unnamed: 0                                           fullText     pubTime  \
# 0           0  Бабушкинский суд столицы приговорил трех актив...  2024-02-19
# 1           1  Бывшего совладельца сетей "Кофе хауз" и "Азбук...  2024-02-19
# 2           2  Ежегодный фестиваль исторических садов пройдет...  2024-02-19
# 3           3  На улицах Москвы появилось свыше 120 светоотра...  2024-02-19
# 4           4  Три дома, в которых в свое время жили сотрудни...  2024-02-19
#
#          predicted_by_gemini  \
# 0               происшествия
# 1              мошенничество
# 2  садово-парковое искусство
# 3   городская инфраструктура
# 4              ремонт зданий
#
#                                                 text  \
# 0  Бабушкинский суд столицы приговорил трех актив...
# 1  Бывшего совладельца сетей "Кофе хауз" и "Азбук...
# 2  Ежегодный фестиваль исторических садов пройдет...
# 3  На улицах Москвы появилось свыше 120 светоотра...
# 4  Три дома, в которых в свое время жили сотрудни...
#
#                        topic                    cluster_name
# 0               происшествия                    происшествия
# 1              мошенничество                   мошенничество
# 2  садово-парковое искусство  поисково-спасательная операция
# 3   городская инфраструктура        городская инфраструктура
# 4              ремонт зданий                        некролог

# %% [markdown]
# **text** column would be our input data (X)
# **cluster_name** (Y) is the grouped topic (to which we've added several subtopic on the previous stage (applicatiob of CLIP model +kmeans))
#
# as transformer models accept Y variable ids which start with 0, we will map now **cluster_name** again to digits from 0 to 249.

# %%
labels_dt = pd.DataFrame({'cluster_name' : data_for_training['cluster_name'].unique(), 'roberta_label': [i for i in range(250)]})
labels_dt
# Out:
#                           cluster_name  roberta_label
# 0                         происшествия              0
# 1                        мошенничество              1
# 2       поисково-спасательная операция              2
# 3             городская инфраструктура              3
# 4                             некролог              4
# ..                                 ...            ...
# 245                             моряки            245
# 246                 мелкое хулиганство            246
# 247                  миграция животных            247
# 248                     парусный спорт            248
# 249  строительство скоростного трамвая            249
#
# [250 rows x 2 columns]

# %%
data_for_training = data_for_training.merge(labels_dt, on = 'cluster_name', how = 'left')

# %%
# create sample by topic, because on full data Colab fails to OOM, just to show an example of working fine-tuning
data_for_training = data_for_training[data_for_training['roberta_label'].isin([0,1,2,3,4,5])]

# %%
len(data_for_training)
# Out:
# 376

# %% [markdown]
# ### Fine Tuning XLM RoBERTa

# %%
from sklearn.metrics import accuracy_score, roc_curve, auc
import matplotlib.pyplot as plt

def evaluate_model(classes_predicted, y_true):
    # Get accuracy over the test set
    accuracy = accuracy_score(y_true, classes_predicted)
    print(f'Accuracy: {accuracy*100:.2f}%')

    # Get Confusion Matrix
    cm = confusion_matrix(y_true, classes_predicted)
    print(cm)

    return accuracy

# %%
import numpy as np
import random
import json
import torch
import transformers
import torch.nn as nn

from transformers import (
    AdamW,
    AutoModel,
    AutoTokenizer,
    AutoModelForMaskedLM,
    AutoModelForSequenceClassification,
    BertTokenizer,
    BertForSequenceClassification,
    XLMRobertaTokenizer,
    XLMRobertaForSequenceClassification
)
from transformers import TrainingArguments, Trainer
from sklearn.metrics import (
    confusion_matrix,
    accuracy_score,
    precision_score,
    recall_score,
    f1_score,
    classification_report
)
from sklearn.model_selection import train_test_split

# %%
from transformers import AutoTokenizer

MODEL = 'xlm-roberta-base'

# Load the tokenizer
tokenizer = AutoTokenizer.from_pretrained(MODEL)

# Create a function to tokenize a set of texts
def preprocessing_for_bert(data):
    """Perform required preprocessing steps for pretrained BERT.
    @param    data (np.array): Array of texts to be processed.
    @return   input_ids (torch.Tensor): Tensor of token ids to be fed to a model.
    @return   attention_masks (torch.Tensor): Tensor of indices specifying which
                  tokens should be attended to by the model.
    """
    # Create empty lists to store outputs
    input_ids = []
    attention_masks = []

    # For every sentence...
    for sent in data:
        # `encode_plus` will:
        #    (1) Tokenize the sentence
        #    (2) Add the `[CLS]` and `[SEP]` token to the start and end
        #    (3) Truncate/Pad sentence to max length
        #    (4) Map tokens to their IDs
        #    (5) Create attention mask
        #    (6) Return a dictionary of outputs
        encoded_sent = tokenizer.encode_plus(
            text=text_preprocessing(sent),  # Preprocess sentence
            add_special_tokens=True,        # Add `[CLS]` and `[SEP]`
            max_length=MAX_LEN,                  # Max length to truncate/pad
            pad_to_max_length=True,         # Pad sentence to max length
            #return_tensors='pt',           # Return PyTorch tensor
            return_attention_mask=True      # Return attention mask
            )

        # Add the outputs to the lists
        input_ids.append(encoded_sent.get('input_ids'))
        attention_masks.append(encoded_sent.get('attention_mask'))

    # Convert lists to tensors
    input_ids = torch.tensor(input_ids)
    attention_masks = torch.tensor(attention_masks)

    return input_ids, attention_masks

# %%
# %%time

import torch
import torch.nn as nn
from transformers import XLMRobertaTokenizer, XLMRobertaForSequenceClassification, AdamW, get_linear_schedule_with_warmup

class XLMRobertaFineTuner(nn.Module):
    def __init__(self, num_classes, pretrained_model_name='xlm-roberta-base'):
        super(XLMRobertaFineTuner, self).__init__()
        self.tokenizer = XLMRobertaTokenizer.from_pretrained(pretrained_model_name)
        self.model = XLMRobertaForSequenceClassification.from_pretrained(pretrained_model_name, num_labels=num_classes)
        self.num_classes = num_classes

    def forward(self, input_ids, attention_mask):
        outputs = self.model(input_ids=input_ids, attention_mask=attention_mask)
        return outputs.logits

    def encode_text(self, text_list, max_length=512, padding='max_length', truncation=True, return_tensors='pt'):
        return self.tokenizer(text_list, padding=padding, truncation=truncation, max_length=max_length, return_tensors=return_tensors)

    def get_optimizer_and_scheduler(self, learning_rate, total_steps, warmup_steps):
        optimizer = AdamW(self.model.parameters(), lr=learning_rate)
        scheduler = get_linear_schedule_with_warmup(optimizer, num_warmup_steps=warmup_steps, num_training_steps=total_steps)
        return optimizer, scheduler

def train(model, dataloader, optimizer, scheduler, device, num_epochs):
    model = nn.DataParallel(model, device_ids=[0, 1])
    model.train()
    model.to(device)
    criterion = nn.CrossEntropyLoss()

    for epoch in range(num_epochs):
        total_loss = 0
        for batch in dataloader:
            input_ids, attention_mask, labels = tuple(t.to(device) for t in batch)

            optimizer.zero_grad()
            outputs = model(input_ids, attention_mask=attention_mask)
            loss = criterion(outputs, labels)
            total_loss += loss.item()

            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)  # Gradient clipping to prevent exploding gradients
            optimizer.step()
            scheduler.step()

        print(f"Epoch {epoch+1}/{num_epochs}, Loss: {total_loss/len(dataloader):.4f}")
# Out:
# CPU times: user 44 µs, sys: 0 ns, total: 44 µs
# Wall time: 45.5 µs

# %% [markdown]
# #### Split data to train/test and tokenize

# %%
from torch.utils.data import TensorDataset, DataLoader, RandomSampler, SequentialSampler
import torch
batch_size = 4

# Specify `MAX_LEN`
MAX_LEN = 512
num_classes = len(data_for_training['cluster_name'].unique())
learning_rate = 4e-5
total_steps = 1000
warmup_steps = 100
num_epochs = 2

dev = 'cpu'
device = torch.device(dev)

# %%
X_train, X_test, y_train, y_test = train_test_split(data_for_training['text'], data_for_training['roberta_label'], test_size=0.5, random_state=42)

# %%
# Run function `preprocessing_for_bert` on the train set and the validation set
print('Tokenizing data...')
train_inputs, train_masks = preprocessing_for_bert(X_train)
val_inputs, val_masks = preprocessing_for_bert(X_test)
# Out:
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Tokenizing data...
# /usr/local/lib/python3.10/dist-packages/transformers/tokenization_utils_base.py:2645: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   warnings.warn(

# %% [markdown]
# #### Fine tune (train) step

# %%
# Convert other data types to torch.Tensor
train_labels = torch.tensor(y_train.values)
val_labels = torch.tensor(y_test.values)

# Create the DataLoader for our training set
train_data = TensorDataset(train_inputs, train_masks, train_labels)
train_sampler = RandomSampler(train_data)
train_dataloader = DataLoader(train_data, sampler=train_sampler, batch_size=batch_size)

# Create the DataLoader for our validation set
val_data = TensorDataset(val_inputs, val_masks, val_labels)
val_sampler = SequentialSampler(val_data)
val_dataloader = DataLoader(val_data, sampler=val_sampler, batch_size=batch_size)


torch.cuda.empty_cache()

model = XLMRobertaFineTuner(num_classes)
optimizer, scheduler = model.get_optimizer_and_scheduler(learning_rate, total_steps, warmup_steps)


device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
train(model, train_dataloader, optimizer, scheduler, device, num_epochs)
# Out:
# Some weights of XLMRobertaForSequenceClassification were not initialized from the model checkpoint at xlm-roberta-base and are newly initialized: ['classifier.dense.bias', 'classifier.dense.weight', 'classifier.out_proj.bias', 'classifier.out_proj.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# /usr/local/lib/python3.10/dist-packages/transformers/optimization.py:429: FutureWarning: This implementation of AdamW is deprecated and will be removed in a future version. Use the PyTorch implementation torch.optim.AdamW instead, or set `no_deprecation_warning=True` to disable this warning
#   warnings.warn(
# Epoch 1/2, Loss: 1.6783
# Epoch 2/2, Loss: 1.4680

# %%
import os

def save_model(model, output_dir):
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)
    model_to_save = model.model.module if hasattr(model.model, 'module') else model.model
    model_to_save.save_pretrained(output_dir)
    print(f"Model saved at {output_dir}")

save_model(model, output_dir = '/content/')
# Out:
# Model saved at /content/

# %%
def predict_via_model(text):
    inputs = tokenizer(text, return_tensors="pt", padding=True, truncation=True).to(device)
    output = model(**inputs)
    predicted_class = torch.argmax(output, axis=-1)[0]
    return int(predicted_class)

# %%
classes_prediction_example = X_test[0:5].apply(predict_via_model)

# %%
classes_prediction_example
# Out:
# 6345    1
# 7755    5
# 5581    5
# 3277    1
# 2946    1
# Name: text, dtype: int64

# %%
y_test[0:5]
# Out:
# 6345    1
# 7755    1
# 5581    3
# 3277    1
# 2946    0
# Name: roberta_label, dtype: int64

# %% [markdown]
# # Conclutions
#
# I received a set of texts witout topics and created initial topics using Prompt Engineering and Gemini model (free version) from Google, which gave stable and very good by quality results.
# After that, I moved to improvement to decrease future costs, decided to use Gemini topics as labels for transformers fine-tuning, to be able to use our own model on new data.
#
# I used very small sample and epochs = 2 for fine-tune because of Colab restrictions and long processing by time on cpu, also I've shown predict only on several examples (where 3 from 5 are correct ones).
# Together with it, I've added evaluate_model() function which can calculate accuracy and prints confusion matrix on all test data in the future.
#
# For the brief look and beginning, looks like task is resolvable by suggested approach.
